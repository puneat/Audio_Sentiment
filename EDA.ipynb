# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavipandey99/Audio_Sentiment/blob/pallu/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import matplotlib.pyplot as plt
import glob as glob
import librosa as lr
import IPython.display as ipd

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
file_1 = "/gdrive/My Drive/Audio_files/male_final/RAVDESS/Angry/03-01-05-01-01-01-01.wav"
file_2 = "/gdrive/My Drive/Audio_files/female_final/RAVDESS/Happy/03-01-03-01-01-01-06.wav"
file_3 = "/gdrive/My Drive/Audio_files/male_final/SAVEE/n32.wav"
file_4 = "/gdrive/My Drive/Audio_files/female_final/TESS/Angry/YAF_angry/YAF_back_angry.wav"

# audio_files=glob(dir_1 + '/*.wav')
# len(audio_files)

# %%
audio1,freq1=lr.load(file_1)
t1=np.arange(0,len(audio1))/freq1
audio2,freq2=lr.load(file_2)
t2=np.arange(0,len(audio2))/freq2
audio3,freq3=lr.load(file_3)
t3=np.arange(0,len(audio3))/freq3
audio4,freq4=lr.load(file_4)
t4=np.arange(0,len(audio4))/freq4
ipd.Audio(file_1)
ipd.Audio(file_2)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.style.use('ggplot')
fig = plt.figure(facecolor='w',figsize=(20,10)) 
ax1 = fig.add_subplot(221, axisbelow=True,facecolor='#dbdbdb')
ax2 = fig.add_subplot(222, axisbelow=True,facecolor='#30475e')
ax3 = fig.add_subplot(223, axisbelow=True,facecolor='#dbdbdb')
ax4 = fig.add_subplot(224, axisbelow=True,facecolor='#30475e')
cols = np.linspace(1, 512, 512)
ax1.plot(t1,audio1,color='#d92027')
ax1.set_title('Angry-RAVDESS-Male')
ax1.set(xlabel='Time',ylabel='Amplitude')
ax2.plot(t2,audio2,color='#fcbf1e')
ax2.set_title('Happy-RAVDESS-Female')
ax2.set(xlabel='Time',ylabel='Amplitude')
ax3.plot(t3,audio3,color='#679b9b')
ax3.set_title('Neutral-SAVEE-Male')
ax4.set(xlabel='Time',ylabel='Amplitude')
ax4.plot(t4,audio4,color='#d92027')
ax4.set_title('Angry-TESS-Female')
ax4.set(xlabel='Time',ylabel='Amplitude')
plt.show()
